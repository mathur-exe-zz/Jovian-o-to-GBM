# %%
# !pip list | grep opendatasets

# %%
# !pip install opendatasets

# %%
import pandas as pd
import numpy as np
import opendatasets as od
import os

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
od.download('https://www.kaggle.com/c/rossmann-store-sales')
# Out:
# ...
# 100%|██████████| 6.99M/6.99M [00:00<00:00, 119MB/s]
# Extracting archive ./rossmann-store-sales/rossmann-store-sales.zip to ./rossmann-store-sales

# %%
os.listdir('rossmann-store-sales')
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv', 'store.csv']

# %%
train_df = pd.read_csv('./rossmann-store-sales/train.csv', low_memory=False)
store_df = pd.read_csv('./rossmann-store-sales/store.csv')
test_df = pd.read_csv('./rossmann-store-sales/test.csv')
sub_df = pd.read_csv('./rossmann-store-sales/sample_submission.csv')

# %%
train_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
test_df
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...

# %%
sub_df
# Out:
#           Id  Sales
# 0          1      0
# 1          2      0
# 2          3      0
# 3          4      0
# 4          5      0
# ...      ...    ...
# 41083  41084      0
# 41084  41085      0
# 41085  41086      0
# 41086  41087      0
# 41087  41088      0
#
# [41088 rows x 2 columns]

# %%
store_df
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
train_df = train_df.merge(store_df, how='left', on='Store')
test_df = test_df.merge(store_df, how='left', on='Store')

# %%
train_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
train_df.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday  CompetitionDistance  \
# count  1.017209e+06   1.017209e+06         1.014567e+06
# mean   3.815145e-01   1.786467e-01         5.430086e+03
# std    4.857586e-01   3.830564e-01         7.715324e+03
# min    0.000000e+00   0.000000e+00         2.000000e+01
# ...

# %%
train_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
train_df.corr()
# Out:
#                               Store  DayOfWeek     Sales  Customers      Open  \
# Store                      1.000000  -0.000008  0.005126   0.024325 -0.000047
# DayOfWeek                 -0.000008   1.000000 -0.462125  -0.386445 -0.528963
# Sales                      0.005126  -0.462125  1.000000   0.894711  0.678472
# Customers                  0.024325  -0.386445  0.894711   1.000000  0.616768
# Open                      -0.000047  -0.528963  0.678472   0.616768  1.000000
# Promo                      0.000058  -0.392925  0.452345   0.316169  0.295042
# SchoolHoliday              0.000641  -0.205388  0.085124   0.071568  0.086171
# CompetitionDistance       -0.026413  -0.000025 -0.019229  -0.102861  0.007992
# CompetitionOpenSinceMonth -0.050746   0.000006 -0.028257  -0.030954  0.001384
# CompetitionOpenSinceYear  -0.004592  -0.000025  0.012659   0.008931  0.002771
# Promo2                     0.008488   0.000168 -0.091040  -0.150159 -0.008309
# ...

# %%
# sns.scatterplot(x=train_df.Customers, y=train_df.Sales)
# sns.barplot(x=train_df.DayOfWeek, y=train_df.Sales)

# %%
# sns.barplot(x=train_df.DayOfWeek, y=train_df.Customers);

# %%
# # sns.scatterplot(x=train_df.CompetitionDistance, y=train_df.Customers, 
#                 hue=train_df.Open);

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  object
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
# ...

# %%
def split_data(df):
  df['Date'] = pd.to_datetime(df['Date'])
  df['Year'] = df.Date.dt.year
  df['Month'] = df.Date.dt.month
  df['Day'] = df.Date.dt.day
  df['WeekOfYear'] = df.Date.dt.isocalendar().week

# %%
split_data(train_df)
split_data(test_df)

# %%
train_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          2 2013-01-01      0          0     0      0
# 1017205   1112          2 2013-01-01      0          0     0      0
# 1017206   1113          2 2013-01-01      0          0     0      0
# 1017207   1114          2 2013-01-01      0          0     0      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionOpenSinceMonth  \
# ...

# %%
train_df[train_df.Open == 0].Sales.value_counts()
# Out:
# 0    172817
# Name: Sales, dtype: int64

# %%
train_df = train_df[train_df.Open == 1].copy()

# %%
train_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionOpenSinceMonth  \
# ...

# %%
train_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval', 'Year', 'Month', 'Day',
#        'WeekOfYear'],
#       dtype='object')

# %%
def comp_month(df):
  df['Comp_Open'] = 12 * (df.Year - df.CompetitionOpenSinceYear) + (df.Month - df.CompetitionOpenSinceMonth)
  df['Comp_Open'] = df['Comp_Open'].map(lambda x: 0 if x < 0 else x).fillna(0)

# %%
comp_month(train_df)
comp_month(test_df)

# %%
train_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval', 'Year', 'Month', 'Day',
#        'WeekOfYear', 'Comp_Open'],
#       dtype='object')

# %%
train_df[['Date', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Comp_Open']]
# Out:
#               Date  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0       2015-07-31               1270.0                        9.0
# 1       2015-07-31                570.0                       11.0
# 2       2015-07-31              14130.0                       12.0
# 3       2015-07-31                620.0                        9.0
# 4       2015-07-31              29910.0                        4.0
# ...            ...                  ...                        ...
# 1016776 2013-01-01                150.0                        9.0
# 1016827 2013-01-01                860.0                       10.0
# 1016863 2013-01-01                840.0                        NaN
# 1017042 2013-01-01               1430.0                        NaN
# 1017190 2013-01-01                720.0                        3.0
#
#          CompetitionOpenSinceYear  Comp_Open
# 0                          2008.0       82.0
# 1                          2007.0       92.0
# ...

# %%
def check_promo_month(row):
  month2str = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun',              
                 7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
  try:
    months = (row['PromoInterval'] or '').split(',')
    if row['Promo2Open'] and month2str[row['Month']] in months:
      return 1
    else:
      return 0
  except Exception:
    return 0

def promo_cols(df):
  # Months since Promo2 was open
  df['Promo2Open'] = 12 * (df.Year - df.Promo2SinceYear) + (df.WeekOfYear - df.Promo2SinceWeek)*7/30.5
  df['Promo2Open'] = df['Promo2Open'].map(lambda x: 0 if x < 0 else x).fillna(0) * df['Promo2']

  # Whether a new round of promotions was started in the current month
  df['IsPromo2Month'] = df.apply(check_promo_month, axis=1) * df['Promo2']

# %%
promo_cols(train_df)
promo_cols(test_df)

# %%
train_df[['Date', 'Promo2', 'Promo2SinceYear', 'Promo2SinceWeek', 'PromoInterval', 'Promo2Open', 'IsPromo2Month']]
# Out:
#               Date  Promo2  Promo2SinceYear  Promo2SinceWeek    PromoInterval  \
# 0       2015-07-31       0              NaN              NaN              NaN
# 1       2015-07-31       1           2010.0             13.0  Jan,Apr,Jul,Oct
# 2       2015-07-31       1           2011.0             14.0  Jan,Apr,Jul,Oct
# 3       2015-07-31       0              NaN              NaN              NaN
# 4       2015-07-31       0              NaN              NaN              NaN
# ...            ...     ...              ...              ...              ...
# 1016776 2013-01-01       0              NaN              NaN              NaN
# 1016827 2013-01-01       0              NaN              NaN              NaN
# 1016863 2013-01-01       1           2012.0             48.0  Jan,Apr,Jul,Oct
# 1017042 2013-01-01       0              NaN              NaN              NaN
# 1017190 2013-01-01       0              NaN              NaN              NaN
#
# ...

# %%
train_df.describe()
# Out:
#                Store      DayOfWeek          Sales      Customers      Open  \
# count  844392.000000  844392.000000  844392.000000  844392.000000  844392.0
# mean      558.422920       3.520361    6955.514291     762.728395       1.0
# std       321.731914       1.723689    3104.214680     401.227674       0.0
# min         1.000000       1.000000       0.000000       0.000000       1.0
# 25%       280.000000       2.000000    4859.000000     519.000000       1.0
# 50%       558.000000       3.000000    6369.000000     676.000000       1.0
# 75%       837.000000       5.000000    8360.000000     893.000000       1.0
# max      1115.000000       7.000000   41551.000000    7388.000000       1.0
#
#                Promo  SchoolHoliday  CompetitionDistance  \
# count  844392.000000  844392.000000        842206.000000
# mean        0.446352       0.193580          5457.979627
# std         0.497114       0.395103          7809.437311
# ...

# %%
train_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval', 'Year', 'Month', 'Day',
#        'WeekOfYear', 'Comp_Open', 'Promo2Open', 'IsPromo2Month'],
#       dtype='object')

# %%
input_col = ['Store', 'DayOfWeek', 'Promo', 'StateHoliday', 'SchoolHoliday', 
             'StoreType', 'Assortment', 'CompetitionDistance', 'Comp_Open', 
              'Day', 'Month', 'Year', 'WeekOfYear',  'Promo2', 
              'Promo2Open', 'IsPromo2Month']
target_col = 'Sales'

# %%
inputs = train_df[input_col].copy()
targets = train_df[target_col].copy()

test_inputs = test_df[input_col]

# %%
numeric_col = ['Store', 'Promo', 'SchoolHoliday', 
               'CompetitionDistance', 'Comp_Open', 'Promo2', 'Promo2Open', 'IsPromo2Month', 
               'Day', 'Month', 'Year', 'WeekOfYear']
cat_col = ['DayOfWeek', 'StateHoliday', 'StoreType', 'Assortment']

# %%
inputs[numeric_col].isna().sum()
# Out:
# Store                     0
# Promo                     0
# SchoolHoliday             0
# CompetitionDistance    2186
# Comp_Open                 0
# Promo2                    0
# Promo2Open                0
# IsPromo2Month             0
# Day                       0
# Month                     0
# Year                      0
# WeekOfYear                0
# dtype: int64

# %%
test_inputs[numeric_col].isna().sum()
# Out:
# Store                   0
# Promo                   0
# SchoolHoliday           0
# CompetitionDistance    96
# Comp_Open               0
# Promo2                  0
# Promo2Open              0
# IsPromo2Month           0
# Day                     0
# Month                   0
# Year                    0
# WeekOfYear              0
# dtype: int64

# %%
max_distance = inputs.CompetitionDistance.max()

inputs['CompetitionDistance'].fillna(max_distance, inplace=True)
test_inputs['CompetitionDistance'].fillna(max_distance, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler().fit(inputs[numeric_col])

inputs[numeric_col] = scaler.transform(inputs[numeric_col])
test_inputs[numeric_col] = scaler.transform(test_inputs[numeric_col])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(sparse=False, handle_unknown='ignore').fit(inputs[cat_col])
enc_col = list(enc.get_feature_names(cat_col))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
inputs[enc_col] = enc.transform(inputs[cat_col])
test_inputs[enc_col] = enc.transform(test_inputs[cat_col])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
inputs = inputs[numeric_col + enc_col]
test_inputs = test_inputs[numeric_col + enc_col]

# %%
from xgboost import XGBRegressor

# ?XGBRegressor

# %%
model = XGBRegressor(random_state=42, n_jobs=-1, n_estimators=20, max_depth=4)
